# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\mohamed\OneDrive\Documents\GitHub\Intelligent-Support-Ticket\Project Implementation\Data\Demo.csv")
df.head()
# Out:
#             created_at customer_segment channel product_area      issue_type  \
# 0  2024-01-31T05:14:27       individual   email  data_export  account_access
# 1  2024-01-31T05:14:27       individual   email  data_export             NaN
# 2  2024-01-31T05:14:27       individual   email  data_export             NaN
# 3  2024-01-31T05:14:27       individual   email  data_export             NaN
# 4  2024-01-31T05:14:27       individual   email  data_export             NaN
#
#   priority    status  sla_plan  \
# 0      low  resolved  standard
# 1      low  resolved  standard
# 2      low  resolved  standard
# 3      low  resolved  standard
# 4      low  resolved  standard
#
#                                      initial_message  \
# 0  I cannot log in; the system says my password i...
# 1  Currently dealing with this issue: i cannot ac...
# 2  It appears that i cannot sign in; the system s...
# 3  It appears that i cannot access my account; th...
# ...

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# %%
df['refined_issue'].value_counts()
# Out:
# refined_issue
# performance_timeout            549
# bug_error                      543
# billing_invoice_issue          516
# feature_request_new            509
# account_password_issue         403
# bug_ui_issue                   397
# performance_slow               396
# how_to_configuration           378
# bug_data_loss                  354
# feature_request_improvement    341
# how_to_usage                   334
# account_locked                 316
# performance_crash              290
# security_compliance            281
# security_alert                 267
# security_vulnerability         254
# billing_subscription_issue     234
# network_issue                  221
# email_issue                    197
# general_inquiry                195
# permissions_issue              188
# software_issue                 186
# hardware_issue                 185
# printer_issue                  179
# performance_issue              174
# account_access                 141
# ...

# %%
df['initial_message'].nunique()
# Out:
# 7132

# %%
df['initial_message'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.dropna(subset=['initial_message'], inplace=True)

# %%
df.shape
# Out:
# (8072, 19)

# %%
df.to_csv(r"C:\Users\mohamed\OneDrive\Documents\GitHub\Intelligent-Support-Ticket\Project Implementation\Data\Final_version.csv", index=False)
